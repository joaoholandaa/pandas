# %%
import pandas as pd

# %%
idades = [30, 42, 90, 34]
idades
# Out:
# [30, 42, 90, 34]

# %%
series_idades = pd.Series(idades)
series_idades
# Out:
# 0    30
# 1    42
# 2    90
# 3    34
# dtype: int64

# %%
series_idades.mean()
# Out:
# np.float64(49.0)

# %%
series_idades.var()
# Out:
# np.float64(772.0)

# %%
series_idades.median()
# Out:
# np.float64(38.0)

# %%
series_idades.std()
# Out:
# np.float64(27.784887978899608)

# %%
series_idades.quantile(0.25)
# Out:
# np.float64(33.0)

# %%
series_idades.quantile(0.75)
# Out:
# np.float64(54.0)

# %%
series_idades.describe()
# Out:
# count     4.000000
# mean     49.000000
# std      27.784888
# min      30.000000
# 25%      33.000000
# 50%      38.000000
# 75%      54.000000
# max      90.000000
# dtype: float64

# %%
series_idades.shape
# Out:
# (4,)

# %%
idades[0]
# Out:
# 30

# %%
series_idades[0]
# Out:
# np.int64(30)

# %%
series_idades.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
series_idades.index = ['t', 'e', 'o', 'c']

# %%
series_idades
# Out:
# t    30
# e    42
# o    90
# c    34
# dtype: int64

# %%
series_idades['t']
# Out:
# np.int64(30)

# %%
series_idades[0]
# Out:
# C:\Users\Holanda\AppData\Local\Temp\ipykernel_4588\40611080.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   series_idades[0]
# np.int64(30)

# %%
series_idades.iloc[0]
# Out:
# np.int64(30)

# %%
series_idades.index = [40, 10, 30, 20]
series_idades
# Out:
# 40    30
# 10    42
# 30    90
# 20    34
# dtype: int64

# %%
series_idades.iloc[0]
# Out:
# np.int64(30)

# %%
series_idades.iloc[2:4]
# Out:
# 30    90
# 20    34
# dtype: int64

# %%
series_idades.loc[40]
# Out:
# np.int64(30)

# %%
series_idades.name = 'idades'
series_idades
# Out:
# 40    30
# 10    42
# 30    90
# 20    34
# Name: idades, dtype: int64

# %%
series_idades = pd.Series(idades, name="idades")
series_idades
# Out:
# 0    30
# 1    42
# 2    90
# 3    34
# Name: idades, dtype: int64
